# %% [markdown]
# <a href="https://colab.research.google.com/github/JoannaFano/PLNG211-2-OLFU-QC/blob/main/Fano%2C_Joanna_Marie_Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Name: Fano, Joanna Marie F.
#C/Y/S: BSCS 2 YA - 2
#Assignment: Exercise 1

test_score = [26,49,98,87,62,75]
odd = 0
for i in range(len(test_score)):
    if (test_score[i] % 2 != 0):
      odd += test_score[i]

print("The sum of all odd test score is", odd)
# Out:
# The sum of all odd test score is 211

# %% [markdown]
# **Algorithm:**
#
# Step 1: Start
#
# Step 2: Declare the array of test scores
#
# Step 3: Read test_score = [26,49,98,87,62,75]
#
# Step 4: Use for loops:
#
# ```
# for i in range(len(test_score)):
# ```
#
# Step 5: Use if statement:
# ```
# if (test_score[i] % 2 != 0):
# ```
#
# Step 7: Add all odd test score
#
#
# Step 8: End loop
#
#
# Step 9: Display the sum of all odd test score
#
# Step 10: Stop

# %% [markdown]
# ![flowchart.png](data:image/png;base64,...)
